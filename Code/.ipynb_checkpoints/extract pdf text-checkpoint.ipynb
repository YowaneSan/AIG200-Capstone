# %%
import fitz  # PyMuPDF
import os

def extract_text_from_pdf(pdf_path, txt_path):
    # Open the PDF file
    pdf_document = fitz.open(pdf_path)
    text = ""
    
    # Iterate over each page in the PDF
    for page_num in range(len(pdf_document)):
        # Extract text from the page
        page = pdf_document.load_page(page_num)
        text += page.get_text()
    
    # Write the text to a .txt file
    with open(txt_path, 'w', encoding='utf-8') as txt_file:
        txt_file.write(text)
        
    print(f"Text has been successfully extracted to {txt_path}")

# PDF files Directory
pdf_directory = 'Digestive_and_Excretory_System'
"pdf_path = \"C:\\Users\\Jeremy Chong\\Desktop\\School\\Capstone\\AIG200-Capstone\\Dataset\\Circulatory_System\\Heart.pdf\"\n",

# output
output_directory = 'Digestive_and_Excretory_System'
os.makedirs(output_directory, exist_ok=True)

# Loop through all the files in the directory
for filename in os.listdir(pdf_directory):
    if filename.endswith('.pdf'):
        pdf_path = os.path.join(pdf_directory, filename)
        txt_filename = os.path.splitext(filename)[0] + '.txt'
        txt_path = os.path.join(output_directory, txt_filename)
        
        extract_text_from_pdf(pdf_path, txt_path)
# Out:
# Text has been successfully extracted to Digestive_and_Excretory_System\Anus.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Cecum.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Digestion.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Duodenum.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Esophagus.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Gallbladder.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Gastrointestinal_tract.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Gut_microbiota.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Human_digestive_system.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Ileum.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Jejunum.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Large_intestine.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Liver.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Mouth.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Nutrient.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Pancreas.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Salivary_gland.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Small_intestine.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Stomach.txt
# Text has been successfully extracted to Digestive_and_Excretory_System\Suspensory_muscle_of_duodenum.txt

# %%
import nltk
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

txt_path = 'Oxygen.txt'

# with open(txt_path, 'r') as file:
    # text = file.read()
    
# need encode to read specific char
with open(txt_path, 'r', encoding='utf-8') as file:
    text = file.read()
    
tokens = nltk.word_tokenize(text)

stop_words = set(stopwords.words('english'))
tokens = [word for word in tokens if word.isalpha() and word.lower() not in stop_words]

#freq_dist = FreqDist.tokenize(tokens) #notworking 
freq_dist = FreqDist(tokens)

for word, frequency in freq_dist.most_common(20):
    print(f"{word}: {frequency}")

bigram_finder = BigramCollocationFinder.from_words(tokens)

bigrams = bigram_finder.nbest(BigramAssocMeasures.likelihood_ratio, 20)

print("\nTop 20 bigrams:")
for bigram in bigrams:
    print(bigram)
# Out:
# https: 210
# oxygen: 205
# Oxygen: 87
# Archived: 60
# Retrieved: 57
# original: 56
# gas: 54
# http: 51
# pressure: 40
# air: 40
# water: 34
# ISBN: 33
# Earth: 30
# used: 30
# December: 25
# PMID: 25
# atmosphere: 23
# liquid: 21
# also: 20
# September: 20
#
# Top 20 bigrams:
# ('Archived', 'https')
# ('Archived', 'original')
# ('PMID', 'https')
# ('Retrieved', 'December')
# ('years', 'ago')
# ('et', 'al')
# ('Cook', 'Lauer')
# ('partial', 'pressure')
# ('https', 'PMID')
# ('billion', 'years')
# ('carbon', 'dioxide')
# ('Wayback', 'Machine')
# ('original', 'http')
# ('New', 'York')
# ('https', 'original')
# ('Retrieved', 'September')
# ('phlogiston', 'theory')
# ('October', 'Retrieved')
# ('chemical', 'element')
# ('per', 'liter')

# %%
# from transformers import pipeline

# txt_path = 'Oxygen.txt'
# with open(txt_path, 'r', encoding='utf-8') as file:
#     text = file.read()
    
# summarizer = pipeline("summarization")

# def summarize_text(text, max_length=150):
#     summary = summarizer(text, max_length=max_length, min_length=30, do_sample=False)
#     return summary[0]['summary_text']

# summary = summarize_text(text)
# print("Summary:", summary)
